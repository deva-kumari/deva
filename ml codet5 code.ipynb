# %% [markdown]
# <a href="https://colab.research.google.com/github/deva-kumari/deva/blob/main/ml%20codet5%20code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import torch
import numpy as np
import pandas as pd
from transformers import AutoModel, AutoTokenizer

# Load the CodeT5+ model and tokenizer
checkpoint = "Salesforce/codet5p-110m-embedding"
device = "cuda" if torch.cuda.is_available() else "cpu"

tokenizer = AutoTokenizer.from_pretrained(checkpoint, trust_remote_code=True)
model = AutoModel.from_pretrained(checkpoint, trust_remote_code=True).to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/511k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/294k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.37M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# configuration_codet5p_embedding.py:   0%|          | 0.00/2.62k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Salesforce/codet5p-110m-embedding:
# - configuration_codet5p_embedding.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_codet5p_embedding.py:   0%|          | 0.00/1.93k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Salesforce/codet5p-110m-embedding:
# - modeling_codet5p_embedding.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]

# %%
df = pd.read_excel('/content/final ml excel (1).xlsx')
df.head()
# Out:
#                                   code_with_solution  \
# 0  /*\nSum of elements in an array\n*/\n#include ...
# 1  /*\nSum of elements in an array\n*/\n#include ...
# 2  /*\nSum of elements in an array\n*/\n#include ...
# 3  /*\nSum of elements in an array\n*/\n#include ...
# 4  /*\nSum of elements in an array\n*/\n#include ...
#
#                                                 code  \
# 0  #include <stdio.h>\n#define MAX_SIZE 100\nint ...
# 1  #include <stdio.h>\n#define MAX_SIZE 100\nint ...
# 2  #include <stdio.h>\n#define MAX_SIZE 100\nint ...
# 3  #include <stdio.h>\n#define MAX_SIZE 100\nint ...
# 4  #include <stdio.h>\n#define MAX_SIZE 100\nint ...
#
#                                             Solution  \
# 0  #include <stdio.h>\n#define MAX_SIZE 100\nint ...
# 1  #include <stdio.h>\n#define MAX_SIZE 100\nint ...
# 2  #include <stdio.h>\n#define MAX_SIZE 100\nint ...
# 3  #include <stdio.h>\n#define MAX_SIZE 100\nint ...
# 4  #include <stdio.h>\n#define MAX_SIZE 100\nint ...
#
#                       Question  \
# 0  Sum of elements in an array
# 1  Sum of elements in an array
# 2  Sum of elements in an array
# 3  Sum of elements in an array
# 4  Sum of elements in an array
#
#                                              comment
# 0  // For: Iteration over a sequence of elements ...
# 1  // For: Iteration over a sequence of elements ...
# 2  // For: Iteration over a sequence of elements ...
# 3  // For: Iteration over a sequence of elements ...
# 4  // For: Iteration over a sequence of elements ...

# %%
import pandas as pd
import torch
import numpy as np
# import pandas as pd  # No need to import again
from transformers import AutoModel, AutoTokenizer

# Load the CodeT5+ model and tokenizer
checkpoint = "Salesforce/codet5p-110m-embedding"
device = "cuda" if torch.cuda.is_available() else "cpu"

tokenizer = AutoTokenizer.from_pretrained(checkpoint, trust_remote_code=True)
model = AutoModel.from_pretrained(checkpoint, trust_remote_code=True).to(device)

# Function to encode data in batches
def encode_data_batch(df, model, tokenizer, device, start_row, end_row):
    embeddings = []
    for i in range(start_row, end_row):
        code = df['Question'][i]  # Accessing the 'code' column
        inputs = tokenizer.encode(code, return_tensors="pt", max_length=512, truncation=True).to(device)
        with torch.no_grad():
            embedding = model(inputs)[0].cpu().numpy()  # Mean pooling to get fixed-size embeddings
        embeddings.append(embedding)
    return embeddings


# Process the data in batches
batch_size = 300
all_embeddings = []

# Load the DataFrame here to make it available in this cell's scope
df = pd.read_excel('/content/final ml excel (1).xlsx') # Load the dataframe here

start_row = 0
while start_row < len(df):
    end_row = min(start_row + batch_size, len(df))
    embeddings_batch = encode_data_batch(df, model, tokenizer, device, start_row, end_row)
    all_embeddings.extend(embeddings_batch)
    start_row = end_row

# Convert to numpy array and reshape if necessary
embeddings_array = np.vstack(all_embeddings)

# Create DataFrame from embeddings
embedding_columns = [f'Question_embedding_{i}' for i in range(embeddings_array.shape[1])]
Question_df = pd.DataFrame(embeddings_array, columns=embedding_columns)

Question_df
# Out:
#       Question_embedding_0  Question_embedding_1  Question_embedding_2  \
# 0                -0.053950              0.006342             -0.080851
# 1                -0.053950              0.006342             -0.080851
# 2                -0.053950              0.006342             -0.080851
# 3                -0.053950              0.006342             -0.080851
# 4                -0.053950              0.006342             -0.080851
# ...                    ...                   ...                   ...
# 1171             -0.035263              0.088376             -0.004167
# 1172             -0.035263              0.088376             -0.004167
# 1173             -0.035263              0.088376             -0.004167
# 1174             -0.035263              0.088376             -0.004167
# 1175             -0.035263              0.088376             -0.004167
#
#       Question_embedding_3  Question_embedding_4  Question_embedding_5  \
# 0                 0.013424              0.047821              0.051575
# 1                 0.013424              0.047821              0.051575
# 2                 0.013424              0.047821              0.051575
# 3                 0.013424              0.047821              0.051575
# 4                 0.013424              0.047821              0.051575
# ...                    ...                   ...                   ...
# 1171             -0.007825             -0.116845             -0.080715
# 1172             -0.007825             -0.116845             -0.080715
# 1173             -0.007825             -0.116845             -0.080715
# 1174             -0.007825             -0.116845             -0.080715
# 1175             -0.007825             -0.116845             -0.080715
#
#       Question_embedding_6  Question_embedding_7  Question_embedding_8  \
# 0                -0.077619              0.036816             -0.040900
# 1                -0.077619              0.036816             -0.040900
# 2                -0.077619              0.036816             -0.040900
# 3                -0.077619              0.036816             -0.040900
# 4                -0.077619              0.036816             -0.040900
# ...                    ...                   ...                   ...
# 1171             -0.064336              0.087961             -0.024222
# 1172             -0.064336              0.087961             -0.024222
# 1173             -0.064336              0.087961             -0.024222
# 1174             -0.064336              0.087961             -0.024222
# 1175             -0.064336              0.087961             -0.024222
#
#       Question_embedding_9  ...  Question_embedding_246  \
# 0                -0.002109  ...               -0.003386
# 1                -0.002109  ...               -0.003386
# 2                -0.002109  ...               -0.003386
# 3                -0.002109  ...               -0.003386
# 4                -0.002109  ...               -0.003386
# ...                    ...  ...                     ...
# 1171             -0.011837  ...                0.011730
# 1172             -0.011837  ...                0.011730
# 1173             -0.011837  ...                0.011730
# 1174             -0.011837  ...                0.011730
# 1175             -0.011837  ...                0.011730
#
#       Question_embedding_247  Question_embedding_248  Question_embedding_249  \
# 0                   0.093473               -0.014702                0.051892
# 1                   0.093473               -0.014702                0.051892
# 2                   0.093473               -0.014702                0.051892
# 3                   0.093473               -0.014702                0.051892
# 4                   0.093473               -0.014702                0.051892
# ...                      ...                     ...                     ...
# 1171                0.031995               -0.069950                0.059168
# 1172                0.031995               -0.069950                0.059168
# 1173                0.031995               -0.069950                0.059168
# 1174                0.031995               -0.069950                0.059168
# 1175                0.031995               -0.069950                0.059168
#
#       Question_embedding_250  Question_embedding_251  Question_embedding_252  \
# 0                   0.036493                0.070245                0.084161
# 1                   0.036493                0.070245                0.084161
# 2                   0.036493                0.070245                0.084161
# 3                   0.036493                0.070245                0.084161
# 4                   0.036493                0.070245                0.084161
# ...                      ...                     ...                     ...
# 1171                0.121094                0.055187                0.033680
# 1172                0.121094                0.055187                0.033680
# 1173                0.121094                0.055187                0.033680
# 1174                0.121094                0.055187                0.033680
# 1175                0.121094                0.055187                0.033680
#
#       Question_embedding_253  Question_embedding_254  Question_embedding_255
# 0                  -0.061840               -0.021022               -0.014616
# 1                  -0.061840               -0.021022               -0.014616
# 2                  -0.061840               -0.021022               -0.014616
# 3                  -0.061840               -0.021022               -0.014616
# 4                  -0.061840               -0.021022               -0.014616
# ...                      ...                     ...                     ...
# 1171               -0.059796               -0.040884               -0.071232
# 1172               -0.059796               -0.040884               -0.071232
# 1173               -0.059796               -0.040884               -0.071232
# 1174               -0.059796               -0.040884               -0.071232
# 1175               -0.059796               -0.040884               -0.071232
#
# [1176 rows x 256 columns]

# %%
Question_df.to_csv("Question_df.csv", index=False)

# %%
import pandas as pd
import torch
import numpy as np
# import pandas as pd  # No need to import again
from transformers import AutoModel, AutoTokenizer

# Load the CodeT5+ model and tokenizer
checkpoint = "Salesforce/codet5p-110m-embedding"
device = "cuda" if torch.cuda.is_available() else "cpu"

tokenizer = AutoTokenizer.from_pretrained(checkpoint, trust_remote_code=True)
model = AutoModel.from_pretrained(checkpoint, trust_remote_code=True).to(device)

# Function to encode data in batches
def encode_data_batch(df, model, tokenizer, device, start_row, end_row):
    embeddings = []
    for i in range(start_row, end_row):
        code = df['code'][i]  # Accessing the 'code' column
        inputs = tokenizer.encode(code, return_tensors="pt", max_length=512, truncation=True).to(device)
        with torch.no_grad():
            embedding = model(inputs)[0].cpu().numpy()  # Mean pooling to get fixed-size embeddings
        embeddings.append(embedding)
    return embeddings


# Process the data in batches
batch_size = 300
all_embeddings = []

# Load the DataFrame here to make it available in this cell's scope
df = pd.read_excel('/content/final ml excel (1).xlsx') # Load the dataframe here

start_row = 0
while start_row < len(df):
    end_row = min(start_row + batch_size, len(df))
    embeddings_batch = encode_data_batch(df, model, tokenizer, device, start_row, end_row)
    all_embeddings.extend(embeddings_batch)
    start_row = end_row

# Convert to numpy array and reshape if necessary
embeddings_array = np.vstack(all_embeddings)

# Create DataFrame from embeddings
embedding_columns = [f'code_embedding_{i}' for i in range(embeddings_array.shape[1])]
code_df = pd.DataFrame(embeddings_array, columns=embedding_columns)

code_df
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/511k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/294k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.37M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# configuration_codet5p_embedding.py:   0%|          | 0.00/2.62k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Salesforce/codet5p-110m-embedding:
# - configuration_codet5p_embedding.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_codet5p_embedding.py:   0%|          | 0.00/1.93k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Salesforce/codet5p-110m-embedding:
# - modeling_codet5p_embedding.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]
#       code_embedding_0  code_embedding_1  code_embedding_2  code_embedding_3  \
# 0            -0.049668          0.066196         -0.097552          0.095917
# 1            -0.050168          0.066660         -0.096489          0.093809
# 2            -0.048539          0.066679         -0.096430          0.096520
# 3            -0.048557          0.068472         -0.097690          0.096352
# 4            -0.049493          0.066515         -0.096791          0.096202
# ...                ...               ...               ...               ...
# 1171         -0.066601          0.015852         -0.068536         -0.018658
# 1172         -0.073236          0.017119         -0.069176         -0.005492
# 1173         -0.059526          0.041682         -0.114872          0.000993
# 1174         -0.068807          0.020602         -0.065370         -0.009702
# 1175         -0.032615          0.005903         -0.099035          0.027842
#
#       code_embedding_4  code_embedding_5  code_embedding_6  code_embedding_7  \
# 0            -0.119526          0.051670         -0.015767          0.043421
# 1            -0.118207          0.052235         -0.015875          0.042141
# 2            -0.118935          0.052741         -0.014446          0.039864
# 3            -0.119611          0.051270         -0.014727          0.042787
# 4            -0.119957          0.051994         -0.016120          0.043592
# ...                ...               ...               ...               ...
# 1171         -0.133710         -0.005289         -0.086990          0.077736
# 1172         -0.118778         -0.017306         -0.068368          0.068622
# 1173         -0.135916          0.018653         -0.048496          0.060381
# 1174         -0.126208         -0.014652         -0.062319          0.070814
# 1175         -0.132599          0.012858         -0.092099          0.078001
#
#       code_embedding_8  code_embedding_9  ...  code_embedding_246  \
# 0             0.074594         -0.102301  ...           -0.000579
# 1             0.075674         -0.102341  ...            0.000182
# 2             0.072171         -0.100493  ...           -0.002659
# 3             0.075354         -0.101607  ...           -0.002814
# 4             0.074015         -0.102539  ...           -0.000616
# ...                ...               ...  ...                 ...
# 1171         -0.032682         -0.063292  ...            0.005511
# 1172         -0.036358         -0.055202  ...            0.009647
# 1173          0.042420         -0.008986  ...           -0.012225
# 1174         -0.038699         -0.062849  ...            0.003160
# 1175          0.019005         -0.050104  ...           -0.006379
#
#       code_embedding_247  code_embedding_248  code_embedding_249  \
# 0              -0.003026           -0.011759            0.104771
# 1              -0.001907           -0.012589            0.106342
# 2              -0.005950           -0.012769            0.104086
# 3              -0.002156           -0.012078            0.104020
# 4              -0.001730           -0.012922            0.104826
# ...                  ...                 ...                 ...
# 1171            0.015332           -0.033875            0.054124
# 1172            0.031987           -0.034938            0.057238
# 1173           -0.003005           -0.042444            0.029991
# 1174            0.022139           -0.034439            0.060184
# 1175           -0.022096           -0.024150            0.058162
#
#       code_embedding_250  code_embedding_251  code_embedding_252  \
# 0              -0.045026           -0.058768            0.053274
# 1              -0.044799           -0.059612            0.054440
# 2              -0.046256           -0.059395            0.055152
# 3              -0.044301           -0.058862            0.054344
# 4              -0.044990           -0.057775            0.053491
# ...                  ...                 ...                 ...
# 1171            0.001533            0.015981           -0.013937
# 1172            0.026749            0.008379           -0.004294
# 1173           -0.008049            0.015207           -0.001658
# 1174            0.026411            0.007478           -0.010360
# 1175           -0.005660            0.029384           -0.030204
#
#       code_embedding_253  code_embedding_254  code_embedding_255
# 0               0.075888            0.036580           -0.033973
# 1               0.073154            0.034712           -0.030627
# 2               0.075315            0.038119           -0.035543
# 3               0.077014            0.036743           -0.030985
# 4               0.076561            0.035802           -0.033474
# ...                  ...                 ...                 ...
# 1171            0.022824            0.061194           -0.053650
# 1172            0.049498            0.083933           -0.044500
# 1173            0.085398            0.066934            0.045040
# 1174            0.049878            0.081605           -0.051934
# 1175            0.062581            0.065573           -0.059107
#
# [1176 rows x 256 columns]

# %%
code_df.to_csv("code_df.csv", index=False)

# %%
import pandas as pd
import torch
import numpy as np
# import pandas as pd  # No need to import again
from transformers import AutoModel, AutoTokenizer

# Load the CodeT5+ model and tokenizer
checkpoint = "Salesforce/codet5p-110m-embedding"
device = "cuda" if torch.cuda.is_available() else "cpu"

tokenizer = AutoTokenizer.from_pretrained(checkpoint, trust_remote_code=True)
model = AutoModel.from_pretrained(checkpoint, trust_remote_code=True).to(device)

# Function to encode data in batches
def encode_data_batch(df, model, tokenizer, device, start_row, end_row):
    embeddings = []
    for i in range(start_row, end_row):
        code = df['Solution'][i]  # Accessing the 'code' column
        inputs = tokenizer.encode(code, return_tensors="pt", max_length=512, truncation=True).to(device)
        with torch.no_grad():
            embedding = model(inputs)[0].cpu().numpy()  # Mean pooling to get fixed-size embeddings
        embeddings.append(embedding)
    return embeddings


# Process the data in batches
batch_size = 300
all_embeddings = []

# Load the DataFrame here to make it available in this cell's scope
df = pd.read_excel('/content/final ml excel (1).xlsx') # Load the dataframe here

start_row = 0
while start_row < len(df):
    end_row = min(start_row + batch_size, len(df))
    embeddings_batch = encode_data_batch(df, model, tokenizer, device, start_row, end_row)
    all_embeddings.extend(embeddings_batch)
    start_row = end_row

# Convert to numpy array and reshape if necessary
embeddings_array = np.vstack(all_embeddings)

# Create DataFrame from embeddings
embedding_columns = [f'Solution_embedding_{i}' for i in range(embeddings_array.shape[1])]
Solution_df = pd.DataFrame(embeddings_array, columns=embedding_columns)

Solution_df
# Out:
#       Solution_embedding_0  Solution_embedding_1  Solution_embedding_2  \
# 0                -0.049668              0.066196             -0.097552
# 1                -0.049668              0.066196             -0.097552
# 2                -0.049668              0.066196             -0.097552
# 3                -0.049668              0.066196             -0.097552
# 4                -0.049668              0.066196             -0.097552
# ...                    ...                   ...                   ...
# 1171             -0.043628              0.035077             -0.082152
# 1172             -0.043628              0.035077             -0.082152
# 1173             -0.043628              0.035077             -0.082152
# 1174             -0.043628              0.035077             -0.082152
# 1175             -0.043628              0.035077             -0.082152
#
#       Solution_embedding_3  Solution_embedding_4  Solution_embedding_5  \
# 0                 0.095917             -0.119526              0.051670
# 1                 0.095917             -0.119526              0.051670
# 2                 0.095917             -0.119526              0.051670
# 3                 0.095917             -0.119526              0.051670
# 4                 0.095917             -0.119526              0.051670
# ...                    ...                   ...                   ...
# 1171              0.002535             -0.123551             -0.007467
# 1172              0.002535             -0.123551             -0.007467
# 1173              0.002535             -0.123551             -0.007467
# 1174              0.002535             -0.123551             -0.007467
# 1175              0.002535             -0.123551             -0.007467
#
#       Solution_embedding_6  Solution_embedding_7  Solution_embedding_8  \
# 0                -0.015767              0.043421              0.074594
# 1                -0.015767              0.043421              0.074594
# 2                -0.015767              0.043421              0.074594
# 3                -0.015767              0.043421              0.074594
# 4                -0.015767              0.043421              0.074594
# ...                    ...                   ...                   ...
# 1171             -0.049139              0.069310             -0.027799
# 1172             -0.049139              0.069310             -0.027799
# 1173             -0.049139              0.069310             -0.027799
# 1174             -0.049139              0.069310             -0.027799
# 1175             -0.049139              0.069310             -0.027799
#
#       Solution_embedding_9  ...  Solution_embedding_246  \
# 0                -0.102301  ...               -0.000579
# 1                -0.102301  ...               -0.000579
# 2                -0.102301  ...               -0.000579
# 3                -0.102301  ...               -0.000579
# 4                -0.102301  ...               -0.000579
# ...                    ...  ...                     ...
# 1171             -0.075133  ...                0.007845
# 1172             -0.075133  ...                0.007845
# 1173             -0.075133  ...                0.007845
# 1174             -0.075133  ...                0.007845
# 1175             -0.075133  ...                0.007845
#
#       Solution_embedding_247  Solution_embedding_248  Solution_embedding_249  \
# 0                  -0.003026               -0.011759                0.104771
# 1                  -0.003026               -0.011759                0.104771
# 2                  -0.003026               -0.011759                0.104771
# 3                  -0.003026               -0.011759                0.104771
# 4                  -0.003026               -0.011759                0.104771
# ...                      ...                     ...                     ...
# 1171                0.021843               -0.042841                0.044114
# 1172                0.021843               -0.042841                0.044114
# 1173                0.021843               -0.042841                0.044114
# 1174                0.021843               -0.042841                0.044114
# 1175                0.021843               -0.042841                0.044114
#
#       Solution_embedding_250  Solution_embedding_251  Solution_embedding_252  \
# 0                  -0.045026               -0.058768                0.053274
# 1                  -0.045026               -0.058768                0.053274
# 2                  -0.045026               -0.058768                0.053274
# 3                  -0.045026               -0.058768                0.053274
# 4                  -0.045026               -0.058768                0.053274
# ...                      ...                     ...                     ...
# 1171                0.025182                0.009991               -0.013706
# 1172                0.025182                0.009991               -0.013706
# 1173                0.025182                0.009991               -0.013706
# 1174                0.025182                0.009991               -0.013706
# 1175                0.025182                0.009991               -0.013706
#
#       Solution_embedding_253  Solution_embedding_254  Solution_embedding_255
# 0                   0.075888                0.036580               -0.033973
# 1                   0.075888                0.036580               -0.033973
# 2                   0.075888                0.036580               -0.033973
# 3                   0.075888                0.036580               -0.033973
# 4                   0.075888                0.036580               -0.033973
# ...                      ...                     ...                     ...
# 1171                0.046941                0.062362               -0.063706
# 1172                0.046941                0.062362               -0.063706
# 1173                0.046941                0.062362               -0.063706
# 1174                0.046941                0.062362               -0.063706
# 1175                0.046941                0.062362               -0.063706
#
# [1176 rows x 256 columns]

# %%
import pandas as pd
import torch
import numpy as np
from transformers import AutoModel, AutoTokenizer

# Load the CodeT5+ model and tokenizer
checkpoint = "Salesforce/codet5p-110m-embedding"
device = "cuda" if torch.cuda.is_available() else "cpu"

tokenizer = AutoTokenizer.from_pretrained(checkpoint, trust_remote_code=True)
model = AutoModel.from_pretrained(checkpoint, trust_remote_code=True).to(device)

# Function to encode data in batches
def encode_data_batch(df, model, tokenizer, device, start_row, end_row):
    embeddings = []
    for i in range(start_row, end_row):
        try:
            code = df.iloc[i]['comment']  # Use .iloc for safe row access
            if pd.isna(code) or not isinstance(code, str):  # Skip invalid rows
                continue

            inputs = tokenizer.encode(code, return_tensors="pt", max_length=512, truncation=True).to(device)
            with torch.no_grad():
                embedding = model(inputs)[0].cpu().numpy()  # Extract embedding
            embeddings.append(embedding)
        except Exception as e:
            print(f"Error processing row {i}: {e}")  # Log any errors
    return embeddings

# Load the DataFrame
df = pd.read_excel('/content/final ml excel (1).xlsx')

# Process the data in batches
batch_size = 300
all_embeddings = []
start_row = 0

while start_row < len(df):
    end_row = min(start_row + batch_size, len(df))
    embeddings_batch = encode_data_batch(df, model, tokenizer, device, start_row, end_row)
    all_embeddings.extend(embeddings_batch)
    start_row = end_row

# Convert to numpy array
embeddings_array = np.vstack(all_embeddings)

# Create DataFrame from embeddings
embedding_columns = [f'comment_embedding_{i}' for i in range(embeddings_array.shape[1])]
comment_df = pd.DataFrame(embeddings_array, columns=embedding_columns)

comment_df
# Out:
#       comment_embedding_0  comment_embedding_1  comment_embedding_2  \
# 0                0.043828             0.034750             0.056459
# 1                0.043828             0.034750             0.056459
# 2                0.043828             0.034750             0.056459
# 3                0.043828             0.034750             0.056459
# 4                0.043828             0.034750             0.056459
# ...                   ...                  ...                  ...
# 1085             0.090115             0.047919            -0.082011
# 1086             0.037934             0.031067            -0.116121
# 1087             0.089364             0.059966            -0.110220
# 1088             0.090115             0.047919            -0.082011
# 1089             0.090115             0.047919            -0.082011
#
#       comment_embedding_3  comment_embedding_4  comment_embedding_5  \
# 0                0.017442            -0.073978            -0.031304
# 1                0.017442            -0.073978            -0.031304
# 2                0.017442            -0.073978            -0.031304
# 3                0.017442            -0.073978            -0.031304
# 4                0.017442            -0.073978            -0.031304
# ...                   ...                  ...                  ...
# 1085             0.015260            -0.028654            -0.077969
# 1086             0.026018            -0.007670            -0.060623
# 1087             0.001594            -0.038582            -0.029173
# 1088             0.015260            -0.028654            -0.077969
# 1089             0.015260            -0.028654            -0.077969
#
#       comment_embedding_6  comment_embedding_7  comment_embedding_8  \
# 0               -0.082108             0.100116            -0.011710
# 1               -0.082108             0.100116            -0.011710
# 2               -0.082108             0.100116            -0.011710
# 3               -0.082108             0.100116            -0.011710
# 4               -0.082108             0.100116            -0.011710
# ...                   ...                  ...                  ...
# 1085             0.024798             0.058835             0.016121
# 1086             0.002420             0.081096             0.098950
# 1087            -0.004759             0.077391             0.025570
# 1088             0.024798             0.058835             0.016121
# 1089             0.024798             0.058835             0.016121
#
#       comment_embedding_9  ...  comment_embedding_246  comment_embedding_247  \
# 0                0.015122  ...              -0.163746               0.093427
# 1                0.015122  ...              -0.163746               0.093427
# 2                0.015122  ...              -0.163746               0.093427
# 3                0.015122  ...              -0.163746               0.093427
# 4                0.015122  ...              -0.163746               0.093427
# ...                   ...  ...                    ...                    ...
# 1085            -0.028539  ...              -0.014932               0.034906
# 1086            -0.023419  ...              -0.007025               0.045322
# 1087            -0.029977  ...              -0.009274               0.066692
# 1088            -0.028539  ...              -0.014932               0.034906
# 1089            -0.028539  ...              -0.014932               0.034906
#
#       comment_embedding_248  comment_embedding_249  comment_embedding_250  \
# 0                  0.040437               0.006901               0.108592
# 1                  0.040437               0.006901               0.108592
# 2                  0.040437               0.006901               0.108592
# 3                  0.040437               0.006901               0.108592
# 4                  0.040437               0.006901               0.108592
# ...                     ...                    ...                    ...
# 1085               0.012133              -0.002701               0.049955
# 1086               0.021198               0.033131               0.005538
# 1087              -0.008614               0.037456               0.062825
# 1088               0.012133              -0.002701               0.049955
# 1089               0.012133              -0.002701               0.049955
#
#       comment_embedding_251  comment_embedding_252  comment_embedding_253  \
# 0                  0.036561               0.088420              -0.043052
# 1                  0.036561               0.088420              -0.043052
# 2                  0.036561               0.088420              -0.043052
# 3                  0.036561               0.088420              -0.043052
# 4                  0.036561               0.088420              -0.043052
# ...                     ...                    ...                    ...
# 1085              -0.026061              -0.016839              -0.067502
# 1086              -0.010156              -0.037944              -0.051049
# 1087              -0.041846              -0.036222              -0.088300
# 1088              -0.026061              -0.016839              -0.067502
# 1089              -0.026061              -0.016839              -0.067502
#
#       comment_embedding_254  comment_embedding_255
# 0                  0.033313               0.023977
# 1                  0.033313               0.023977
# 2                  0.033313               0.023977
# 3                  0.033313               0.023977
# 4                  0.033313               0.023977
# ...                     ...                    ...
# 1085              -0.081880              -0.053894
# 1086              -0.078965              -0.023518
# 1087              -0.053797              -0.041354
# 1088              -0.081880              -0.053894
# 1089              -0.081880              -0.053894
#
# [1090 rows x 256 columns]

# %%
Solution_df.to_csv("Solution_df.csv", index=False)

# %%
comment_df.to_csv("comment_df.csv", index=False)

# %%
result_df = pd.concat([code_df,Solution_df,Question_df, comment_df], axis=1)
result_df.to_csv("result_df.csv", index=False)
